# %% [markdown]
# <a href="https://colab.research.google.com/github/stgstg27/BasketballExtension/blob/main/NBA_Backend_APIsipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nba_api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.2/257.2 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from nba_api.live.nba.endpoints import scoreboard

# Today's Score Board
games = scoreboard.ScoreBoard()

# json
games.get_json()

# dictionary
games.get_dict()
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2023-05-07 09:01:25.125',
#   'code': 200},
#  'scoreboard': {'gameDate': '2023-05-07',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': [{'gameId': '0042200224',
#     'gameCode': '20230507/DENPHX',
#     'gameStatus': 2,
#     'gameStatusText': 'Q2 02:22',
#     'period': 2,
#     'gameClock': 'PT02M22.00S',
#     'gameTimeUTC': '2023-05-08T00:00:00Z',
#     'gameEt': '2023-05-07T20:00:00-04:00',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': 'Game 4',
#     'seriesText': 'DEN leads 2-1',
#     'seriesConference': 'West',
#     'poRoundDesc': 'Conf. Semifinals',
#     'gameSubtype': '',
#     'homeTeam': {'teamId': 1610612756,
#      'teamName': 'Suns',
#      'teamCity': 'Phoenix',
#      'teamTricode': 'PHX',
#      'wins': 1,
# ...

# %%
from nba_api.stats.endpoints import playercareerstats

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
career.get_data_frames()[0]

# json
career.get_json()

# dictionary
career.get_dict()
# Out:
# {'resource': 'playercareerstats',
#  'parameters': {'PerMode': 'Totals', 'PlayerID': 203999, 'LeagueID': None},
#  'resultSets': [{'name': 'SeasonTotalsRegularSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[203999,
#      '2015-16',
#      '00',
#      1610612743,
#      'DEN',
#      21.0,
#      80,
#      55,
#      1733.0,
#      307,
#      600,
#      0.512,
#      28,
#      84,
#      0.333,
#      154,
#      190,
#      0.811,
#      181,
#      379,
#      560,
#      189,
#      79,
#      50,
#      104,
#      208,
#      796],
#     [203999,
#      '2016-17',
#      '00',
# ...
